# %%
from modules.preprocessing import WeatherPreprocessor, process_and_merge
from modules.data_loader import load_traffic_data

# %%
wp = WeatherPreprocessor()
tdf = load_traffic_data()
# Out:
# 📂 Found 8 traffic files. Loading...
# /Users/amir/Development/Edu/Reading University  Postgraduate Courses/CSMAD  25-6 Applied Data Science with Python S1 /Course work/Course Work 2/02_csmad_cw2/modules/data_loader.py:60: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   raw_df['timestamp'] = pd.to_datetime(
# ✅ Traffic Data Loaded. Rows: 123072
#    Timeframe: 2021-01-27 00:00:00 to 2024-07-31 23:45:00

# %%
raw = wp.load_raw()
print("RAW:", len(raw), raw.index.min(), raw.index.max())

sel = wp.select_columns(raw)
print("SELECTED:", len(sel))

dec = wp.decode(sel)
print("DECODED:", len(dec))

res = wp.resample(dec)
print("RESAMPLED:", len(res), res.index.min(), res.index.max())
# Out:
# RAW: 86824 2021-01-01 00:00:00 2024-09-08 21:20:00
# SELECTED: 86824
# DECODED: 86824
# RESAMPLED: 129302 2021-01-01 00:00:00 2024-09-08 21:15:00

# %%
wdf = wp.run()
wdf.head()
# Out:
#                      temperature_C  dewpoint_C  rel_humidity  wind_dir_deg  \
# timestamp
# 2021-01-01 00:00:00          -1.00       -1.30     97.827639         330.0
# 2021-01-01 00:15:00          -1.05       -1.35     97.826751         335.0
# 2021-01-01 00:30:00          -1.10       -1.40     97.825861         340.0
# 2021-01-01 00:45:00          -1.15       -1.45     97.824972         345.0
# 2021-01-01 01:00:00          -1.20       -1.50     97.824082         350.0
#
#                      wind_speed_ms  visibility_m  pressure_hPa  precip_mm  \
# timestamp
# 2021-01-01 00:00:00           2.10         100.0       1009.60        0.0
# 2021-01-01 00:15:00           1.95         125.0       1009.65        0.0
# 2021-01-01 00:30:00           1.80         150.0       1009.70        0.0
# 2021-01-01 00:45:00           1.65         175.0       1009.75        0.0
# 2021-01-01 01:00:00           1.50         200.0       1009.80        0.0
#
#                      ceiling_m  low_ceiling_flag  cloud_oktas  cloud_pct  \
# timestamp
# 2021-01-01 00:00:00      600.0               0.0          8.0      100.0
# 2021-01-01 00:15:00      600.0               0.0          8.0      100.0
# 2021-01-01 00:30:00      600.0               0.0          8.0      100.0
# 2021-01-01 00:45:00      600.0               0.0          8.0      100.0
# 2021-01-01 01:00:00      600.0               0.0          8.0      100.0
#
#                      obscuration_code obscuration_type  fog_flag  \
# timestamp
# 2021-01-01 00:00:00               0.0             none       0.0
# 2021-01-01 00:15:00               0.0             none       0.0
# 2021-01-01 00:30:00               0.0             none       0.0
# 2021-01-01 00:45:00               0.0             none       0.0
# 2021-01-01 01:00:00               0.0             none       0.0
#
#                      snow_depth_mm  snow_flag  rain_flag ceiling_category
# timestamp
# 2021-01-01 00:00:00            2.0        1.0        0.0              NaN
# 2021-01-01 00:15:00            2.0        1.0        0.0              NaN
# 2021-01-01 00:30:00            2.0        1.0        0.0              NaN
# 2021-01-01 00:45:00            2.0        1.0        0.0              NaN
# 2021-01-01 01:00:00            2.0        1.0        0.0              NaN

# %%
wdf.isnull().sum()
wdf.info()
wdf.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 129302 entries, 2021-01-01 00:00:00 to 2024-09-08 21:15:00
# Freq: 15min
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   temperature_C     129302 non-null  float64
#  1   dewpoint_C        129302 non-null  float64
#  2   rel_humidity      129302 non-null  float64
#  3   wind_dir_deg      129302 non-null  float64
#  4   wind_speed_ms     129302 non-null  float64
#  5   visibility_m      129302 non-null  float64
#  6   pressure_hPa      129302 non-null  float64
#  7   precip_mm         129302 non-null  float64
#  8   ceiling_m         129302 non-null  float64
#  9   low_ceiling_flag  129302 non-null  float64
#  10  cloud_oktas       129302 non-null  float64
#  11  cloud_pct         129302 non-null  float64
#  12  obscuration_code  129302 non-null  float64
#  13  obscuration_type  129302 non-null  object
#  14  fog_flag          129302 non-null  float64
#  15  snow_depth_mm     129302 non-null  float64
#  16  snow_flag         129302 non-null  float64
#  17  rain_flag         129302 non-null  float64
#  18  ceiling_category  129270 non-null  category
# dtypes: category(1), float64(17), object(1)
# memory usage: 18.9+ MB
# temperature_C        4830
# dewpoint_C           4325
# rel_humidity        89824
# wind_dir_deg         1924
# wind_speed_ms        2341
# visibility_m         2491
# pressure_hPa         6577
# precip_mm              40
# ceiling_m            4406
# low_ceiling_flag        2
# cloud_oktas             1
# cloud_pct               1
# obscuration_code        3
# obscuration_type        3
# fog_flag                1
# snow_depth_mm        1165
# snow_flag               2
# rain_flag               2
# ceiling_category        4
# dtype: int64

# %%
tdf.head()
# Out:
#             timestamp  total_volume  avg_mph
# 0 2021-01-27 00:00:00           0.0      NaN
# 1 2021-01-27 00:15:00           0.0      NaN
# 2 2021-01-27 00:30:00           0.0      NaN
# 3 2021-01-27 00:45:00           0.0      NaN
# 4 2021-01-27 01:00:00           0.0      NaN

# %%
merged_df = process_and_merge(traffic_df=tdf,weather_df=wdf)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 123072 entries, 2021-01-27 00:00:00 to 2024-07-31 23:45:00
# Freq: 15min
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   total_volume      123072 non-null  float64
#  1   avg_mph           114687 non-null  float64
#  2   temperature_C     123072 non-null  float64
#  3   dewpoint_C        123072 non-null  float64
#  4   rel_humidity      123072 non-null  float64
#  5   wind_dir_deg      123072 non-null  float64
#  6   wind_speed_ms     123072 non-null  float64
#  7   visibility_m      123072 non-null  float64
#  8   pressure_hPa      123072 non-null  float64
#  9   precip_mm         123072 non-null  float64
#  10  ceiling_m         123072 non-null  float64
#  11  low_ceiling_flag  123072 non-null  float64
#  12  cloud_oktas       123072 non-null  float64
#  13  cloud_pct         123072 non-null  float64
#  14  obscuration_code  123072 non-null  float64
#  15  obscuration_type  123072 non-null  object
#  16  fog_flag          123072 non-null  float64
#  17  snow_depth_mm     123072 non-null  float64
#  18  snow_flag         123072 non-null  float64
#  19  rain_flag         123072 non-null  float64
#  20  ceiling_category  123072 non-null  category
# dtypes: category(1), float64(19), object(1)
# memory usage: 19.8+ MB

# %%
from modules.timeseries import check_stationarity

df = merged_df.copy()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from time_series_models import check_stationarity
#       3 df = merged_df.copy()
#
# ModuleNotFoundError: No module named 'time_series_models'

# %%
# 1. Load merged dataset
df = merged_df  # traffic + weather

# 2. Pick exogenous variables
exog = ["temperature_C", "visibility_m", "precip_mm", "wind_speed_ms"]

# 3. Create forecaster
f = TrafficForecaster(df, target="total_volume")

# 4. Time-based split
f.train_test_split("2024-01-01", exog_cols=exog)

# 5. Fit SARIMAX
f.fit(order=(1,1,1), seasonal_order=(1,1,1,96))

# 6. Forecast
forecast = f.predict()

# 7. Evaluate
f.evaluate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 14
#      11 f.train_test_split("2024-01-01", exog_cols=exog)
#      13 # 5. Fit SARIMAX
# ---> 14 f.fit(order=(1,1,1), seasonal_order=(1,1,1,96))
#      16 # 6. Forecast
#      17 forecast = f.predict()
#
# File ~/Development/Edu/Reading University  Postgraduate Courses/CSMAD  25-6 Applied Data Science with Python S1 /Course work/Course Work 2/02_csmad_cw2/modules/timeseries.py:107, in TrafficForecaster.fit(self, order, seasonal_order, exogenous)
#      97 try:
#      98     self.model = sm.tsa.statespace.SARIMAX(
#      99         endog=self.y_train,
#     100         exog=self.X_train if exogenous else None,
#    (...)    104         enforce_invertibility=False
#     105     )
# --> 107     self.results = self.model.fit()
#     108     return self.results
#     110 except Exception as e:
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/statsmodels/tsa/statespace/mlemodel.py:705, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     703         flags['hessian_method'] = optim_hessian
#     704     fargs = (flags,)
# --> 705     mlefit = super().fit(start_params, method=method,
#     706                          fargs=fargs,
#     707                          maxiter=maxiter,
#     708                          full_output=full_output,
#     709                          disp=disp, callback=callback,
#     710                          skip_hessian=True, **kwargs)
#     712 # Just return the fitted parameters if requested
#     713 if return_params:
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/statsmodels/base/model.py:566, in LikelihoodModel.fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     563     del kwargs["use_t"]
#     565 optimizer = Optimizer()
# --> 566 xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     567                                                fargs, kwargs,
#     568                                                hessian=hess,
#     569                                                method=method,
#     570                                                disp=disp,
#     571                                                maxiter=maxiter,
#     572                                                callback=callback,
#     573                                                retall=retall,
#     574                                                full_output=full_output)
#     575 # Restore cov_type, cov_kwds and use_t
#     576 optim_settings.update(kwds)
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/statsmodels/base/optimizer.py:245, in Optimizer._fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     242     fit_funcs.update(extra_fit_funcs)
#     244 func = fit_funcs[method]
# --> 245 xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     246                      disp=disp, maxiter=maxiter, callback=callback,
#     247                      retall=retall, full_output=full_output,
#     248                      hess=hessian)
#     250 optim_settings = {'optimizer': method, 'start_params': start_params,
#     251                   'maxiter': maxiter, 'full_output': full_output,
#     252                   'disp': disp, 'fargs': fargs, 'callback': callback,
#     253                   'retall': retall, "extra_fit_funcs": extra_fit_funcs}
#     254 optim_settings.update(kwargs)
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/statsmodels/base/optimizer.py:665, in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     663 if SP_LT_116:
#     664     extended_kwargs["disp"]=disp
# --> 665 retvals = optimize.fmin_l_bfgs_b(
#     666     func,
#     667     start_params,
#     668     maxiter=maxiter,
#     669     callback=callback,
#     670     args=fargs,
#     671     bounds=bounds,
#     672     **extended_kwargs
#     673 )
#     676 if full_output:
#     677     xopt, fopt, d = retvals
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/scipy/optimize/_lbfgsb_py.py:281, in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     269 callback = _wrap_callback(callback)
#     270 opts = {'disp': disp,
#     271         'iprint': iprint,
#     272         'maxcor': m,
#    (...)    278         'callback': callback,
#     279         'maxls': maxls}
# --> 281 res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     282                        **opts)
#     283 d = {'grad': res['jac'],
#     284      'task': res['message'],
#     285      'funcalls': res['nfev'],
#     286      'nit': res['nit'],
#     287      'warnflag': res['status']}
#     288 f = res['fun']
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/scipy/optimize/_lbfgsb_py.py:469, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, workers, **unknown_options)
#     461 _lbfgsb.setulb(m, x, low_bnd, upper_bnd, nbd, f, g, factr, pgtol, wa,
#     462                iwa, task, lsave, isave, dsave, maxls, ln_task)
#     464 if task[0] == 3:
#     465     # The minimization routine wants f and g at the current x.
#     466     # Note that interruptions due to maxfun are postponed
#     467     # until the completion of the current minimization iteration.
#     468     # Overwrite f and g:
# --> 469     f, g = func_and_grad(x)
#     470 elif task[0] == 1:
#     471     # new iteration
#     472     n_iterations += 1
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:404, in ScalarFunction.fun_and_grad(self, x)
#     402     self._update_x(x)
#     403 self._update_fun()
# --> 404 self._update_grad()
#     405 return self.f, self.g
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:366, in ScalarFunction._update_grad(self)
#     364 if self._orig_grad in FD_METHODS:
#     365     self._update_fun()
# --> 366 self.g = self._wrapped_grad(self.x, f0=self.f)
#     367 self.g_updated = True
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:41, in _ScalarGradWrapper.__call__(self, x, f0, **kwds)
#      39     g = np.atleast_1d(self.grad(np.copy(x), *self.args))
#      40 elif self.grad in FD_METHODS:
# ---> 41     g, dct = approx_derivative(
#      42         self.fun,
#      43         x,
#      44         f0=f0,
#      45         **self.finite_diff_options,
#      46     )
#      47     self.nfev += dct['nfev']
#      49 self.ngev += 1
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:593, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs, full_output, workers)
#     591 with MapWrapper(workers) as mf:
#     592     if sparsity is None:
# --> 593         J, _nfev = _dense_difference(fun_wrapped, x0, f0, h,
#     594                                  use_one_sided, method,
#     595                                  mf)
#     596     else:
#     597         if not issparse(sparsity) and len(sparsity) == 2:
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:686, in _dense_difference(fun, x0, f0, h, use_one_sided, method, workers)
#     684 f_evals = workers(fun, x_generator2(x0, h))
#     685 dx = [(x0[i] + h[i]) - x0[i] for i in range(n)]
# --> 686 df = [f_eval - f0 for f_eval in f_evals]
#     687 df_dx = [delf / delx for delf, delx in zip(df, dx)]
#     688 nfev += len(df_dx)
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:686, in <listcomp>(.0)
#     684 f_evals = workers(fun, x_generator2(x0, h))
#     685 dx = [(x0[i] + h[i]) - x0[i] for i in range(n)]
# --> 686 df = [f_eval - f0 for f_eval in f_evals]
#     687 df_dx = [delf / delx for delf, delx in zip(df, dx)]
#     688 nfev += len(df_dx)
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/scipy/optimize/_numdiff.py:879, in _Fun_Wrapper.__call__(self, x)
#     876 if xp.isdtype(x.dtype, "real floating"):
#     877     x = xp.astype(x, self.x0.dtype)
# --> 879 f = np.atleast_1d(self.fun(x, *self.args, **self.kwargs))
#     880 if f.ndim > 1:
#     881     raise RuntimeError("`fun` return value has "
#     882                        "more than 1 dimension.")
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/scipy/_lib/_util.py:590, in _ScalarFunctionWrapper.__call__(self, x)
#     587 def __call__(self, x):
#     588     # Send a copy because the user may overwrite it.
#     589     # The user of this class might want `x` to remain unchanged.
# --> 590     fx = self.f(np.copy(x), *self.args)
#     591     self.nfev += 1
#     593     # Make sure the function returns a true scalar
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/statsmodels/base/model.py:534, in LikelihoodModel.fit.<locals>.f(params, *args)
#     533 def f(params, *args):
# --> 534     return -self.loglike(params, *args) / nobs
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/statsmodels/tsa/statespace/mlemodel.py:940, in MLEModel.loglike(self, params, *args, **kwargs)
#     937 if complex_step:
#     938     kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
# --> 940 loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     942 # Koopman, Shephard, and Doornik recommend maximizing the average
#     943 # likelihood to avoid scale issues, but the averaging is done
#     944 # automatically in the base model `fit` method
#     945 return loglike
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/statsmodels/tsa/statespace/kalman_filter.py:1001, in KalmanFilter.loglike(self, **kwargs)
#     985 r"""
#     986 Calculate the loglikelihood associated with the statespace model.
#     987
#    (...)    997     The joint loglikelihood.
#     998 """
#     999 kwargs.setdefault('conserve_memory',
#    1000                   MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# -> 1001 kfilter = self._filter(**kwargs)
#    1002 loglikelihood_burn = kwargs.get('loglikelihood_burn',
#    1003                                 self.loglikelihood_burn)
#    1004 if not (kwargs['conserve_memory'] & MEMORY_NO_LIKELIHOOD):
#
# File /opt/anaconda3/envs/csmad/lib/python3.11/site-packages/statsmodels/tsa/statespace/kalman_filter.py:924, in KalmanFilter._filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     921 self._initialize_state(prefix=prefix, complex_step=complex_step)
#     923 # Run the filter
# --> 924 kfilter()
#     926 return kfilter
#
# KeyboardInterrupt:
